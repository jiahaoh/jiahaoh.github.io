# %% [raw]
# # Sample Jupyter Notebook
#
# This is a demonstration of how Jupyter notebooks can be embedded directly into your al-folio blog posts!
#
# You can include:
# - Code cells with syntax highlighting
# - Mathematical equations
# - Data visualizations
# - Rich markdown content
#
# ## Mathematical Equations
#
# Here's the famous Euler's formula:
#
# $$e^{i\pi} + 1 = 0$$
#
# And here's the quadratic formula:
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$

# %%
# This is a Python code cell
print("Hello from Jupyter notebook!")

# Simple calculation
result = 2 + 2
print(f"2 + 2 = {result}")

# %%
# More complex example
import math

# Create a list of squares
squares = [i**2 for i in range(1, 11)]
print(f"Numbers: {squares}")

# Calculate sum
total = sum(squares)
print(f"Sum of squares from 1 to 10: {total}")

# %% [raw]
# ## Data Analysis Example
#
# You can also include data analysis and visualizations (though you'll need to install the appropriate packages like matplotlib, pandas, etc.)

# %%
# Simple statistics without external libraries
import statistics

data = [1, 2, 3, 4, 5]
mean = statistics.mean(data)
stdev = statistics.stdev(data)

print(f"Sample data points: {data}")
print(f"Mean: {mean}")
print(f"Standard deviation: {stdev:.2f}")

# %% [raw]
# ## How to Use Notebooks in Your Blog
#
# To include a Jupyter notebook in your blog post:
#
# 1. **Create your notebook** in the `assets/jupyter/` directory
# 2. **Reference it in a blog post** using the `jupyter` layout or by including it directly
# 3. **Jekyll will automatically convert** the notebook to HTML when building the site
#
# This makes it perfect for:
# - **Research notebooks** and analysis
# - **Tutorial content** with executable code
# - **Data science projects** and visualizations
# - **Educational content** with interactive examples
#
# Happy coding! 🚀
